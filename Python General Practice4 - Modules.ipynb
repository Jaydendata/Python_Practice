# %% [markdown]
#     ## Common stuff

# %% [markdown]
#     ## file to python

# %%
## Create a txt. file in same directory:

with open("./Testing_creat_txt.txt","a+") as test_txt_file:
    print("Welcome, here's the file contents:")
    test_txt_file.seek(0)
    lines = test_txt_file.readlines()
    for line in lines:
        print(line)
test_txt_file.close()
# Out:
# Welcome, here's the file contents:

# %%
# open and overwrite all in a txt file (w mode):

def write_content():
    with open('Testing Open File.txt','w') as file:
        file.write("This is overwrote from VS Code.")

write_content()

# %%
# read a txt file (r mode):

def read_content():
    with open('Testing Open File.txt','r') as file:
        contents = file.read()
        print(contents)

read_content()
# Out:
# This is overwrote from VS Code.

# %%
# read all lines [specifc line] in a txt (.readlines):

def read_content_readlines():
    with open('Testing Open File.txt','r') as file:
        lines = file.readlines()
        print(lines[0])

read_content_readlines()
# Out:
# This is overwrote from VS Code.

# %%
# read one line at a time (.readline + while):

def read_one_line_at_time():
    with open('Testing Open File.txt','r') as file:
        line = file.readline()
        while line != '':
            print(line)
            line = file.readline()

read_one_line_at_time()
# Out:
# This is overwrote from VS Code.

# %% [markdown]
#     ## JSON

# %%
import json

def display_json():
    with open('C:\Users\user\Downloads\Linkedin Learning\Linkedin_Python Working with Files\02\02_03\begin\monster.json') as file:
        contents = json.load(file)
        print(contents['monsterName'])

display_json()
# Out:
#   Input In [6]
#     with open('C:\Users\user\Downloads\Linkedin Learning\Linkedin_Python Working with Files\02\02_03\begin\monster.json') as file:
#                                                                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
#     ## CSV

# %%
import csv

def read_csv():
    with open ('.\datasets\products.csv') as file:
        contents = csv.reader(file, delimiter= ',')
        for row in contents:
            print(row[0])
read_csv()
# Out:
# product_id
# FUR-ADV-10000002
# FUR-ADV-10000108
# FUR-ADV-10000183
# FUR-ADV-10000188
# FUR-ADV-10000190
# FUR-ADV-10000571
# FUR-ADV-10000600
# FUR-ADV-10000847
# FUR-ADV-10001283
# FUR-ADV-10001440
# FUR-ADV-10001659
# FUR-ADV-10001855
# FUR-ADV-10002329
# FUR-ADV-10002601
# FUR-ADV-10002632
# FUR-ADV-10002889
# FUR-ADV-10003147
# FUR-ADV-10003326
# FUR-ADV-10004159
# FUR-ADV-10004223
# FUR-ADV-10004395
# FUR-ADV-10004499
# FUR-ADV-10004718
# FUR-ADV-10004971
# FUR-BAR-10000560
# FUR-BAR-10000831
# FUR-BAR-10000946
# FUR-BAR-10001039
# FUR-BAR-10002449
# FUR-BAR-10002710
# FUR-BAR-10003465
# FUR-BAR-10003532
# FUR-BAR-10003576
# FUR-BAR-10004434
# FUR-BAR-10004553
# FUR-BAR-10004561
# FUR-BAR-10004682
# FUR-BEV-10000326
# FUR-BEV-10000388
# FUR-BEV-10001048
# FUR-BEV-10001217
# FUR-BEV-10001853
# FUR-BEV-10002193
# FUR-BEV-10002369
# FUR-BEV-10002803
# FUR-BEV-10003414
# FUR-BEV-10004805
# FUR-BEV-10004919
# FUR-BO-10000002
# FUR-BO-10000008
# FUR-BO-10000021
# FUR-BO-10000022
# ...

# %%
response_code = 600
int(str(response_code)[0])
# Out:
# 6

# %%
import os
os.getcwd()
# Out:
# 'f:\\李振寰\\进修 PC\\TAFE NSW Python\\Coding Drafts'

# %%
import pandas as pd

# %%
df_orders = pd.read_csv(r'f:\\李振寰\\进修 PC\\TAFE NSW Python\\Coding Drafts\\orders.csv',sep=',')

# %%
pd.read_csv('.\orders.csv')
# Out:
#                order_id  order_date   ship_date       ship_mode customer_id  \
# 0       AE-2016-1308551  2016-09-28  2016-10-02    Second Class     PO-8865
# 1       AE-2016-1522857  2016-09-04  2016-09-09  Standard Class     PO-8865
# 2        AE-2016-184765  2016-10-03  2016-10-07    Second Class     PO-8865
# 3       AE-2016-1878215  2016-09-15  2016-09-17  Standard Class     PO-8865
# 4        AE-2016-218276  2016-10-09  2016-10-12  Standard Class     PO-8865
# ...                 ...         ...         ...             ...         ...
# 999986   ZI-2020-495856  2020-01-04  2020-01-09    Second Class     JC-5775
# 999987  ZI-2020-5409624  2020-01-13  2020-01-18    Second Class     JC-5775
# 999988  ZI-2020-5478741  2020-01-10  2020-01-10  Standard Class     JC-5775
# 999989  ZI-2020-5986855  2020-01-08  2020-01-11  Standard Class     JC-5775
# 999990   ZI-2020-863102  2020-01-22  2020-01-27  Standard Class     JM-5250
#
# ...

# %%
type(df_orders)
# Out:
# pandas.core.frame.DataFrame

# %%
df_orders.head(3)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0  AE-2016-1308551  2016-09-28  2016-10-02    Second Class     PO-8865
# 1  AE-2016-1522857  2016-09-04  2016-09-09  Standard Class     PO-8865
# 2   AE-2016-184765  2016-10-03  2016-10-07    Second Class     PO-8865
#
#          product_id  sales  quantity  discount  profit  postal_code  region_id
# 0  OFF-FEL-10001405  82.67         2       0.3     0.3          NaN     9954.0
# 1  TEC-EPS-10004171  78.41         6       0.5     0.5          NaN     4792.0
# 2  OFF-FEL-10001405  82.67         2       0.3     0.3          NaN    19848.0

# %%
df_orders.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'product_id', 'sales', 'quantity', 'discount', 'profit', 'postal_code',
#        'region_id'],
#       dtype='object')

# %%
df_orders.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# product_id      object
# sales          float64
# quantity         int64
# discount       float64
# profit         float64
# postal_code    float64
# region_id      float64
# dtype: object

# %%
df_orders.shape
# Out:
# (999991, 12)

# %%
df_orders.index
# Out:
# RangeIndex(start=0, stop=999991, step=1)

# %%
df_orders.rename(columns={'sales':'sales_value'},inplace=True)

# %%
df_orders.head(1)
# Out:
#           order_id  order_date   ship_date     ship_mode customer_id  \
# 0  AE-2016-1308551  2016-09-28  2016-10-02  Second Class     PO-8865
#
#          product_id  sales_value  quantity  discount  profit  postal_code  \
# 0  OFF-FEL-10001405        82.67         2       0.3     0.3          NaN
#
#    region_id
# 0     9954.0

# %%
df_orders.sales_value.head(5)
# Out:
# 0    82.67
# 1    78.41
# 2    82.67
# 3    78.41
# 4    78.41
# Name: sales_value, dtype: float64

# %%
df_orders[['sales_value','customer_id']].head(5)
# Out:
#    sales_value customer_id
# 0        82.67     PO-8865
# 1        78.41     PO-8865
# 2        82.67     PO-8865
# 3        78.41     PO-8865
# 4        78.41     PO-8865

# %%
df_orders.describe()
# Out:
#          sales_value       quantity       discount         profit  \
# count  999991.000000  999991.000000  999991.000000  999991.000000
# mean      245.885888       3.477444       0.247224       1.658624
# std       481.540695       2.285502       0.137232      39.977661
# min         0.440000       1.000000       0.000000   -6599.980000
# 25%        30.680000       2.000000       0.130000       0.100000
# 50%        84.780000       3.000000       0.250000       0.200000
# 75%       250.740000       5.000000       0.350000       0.290000
# max     22638.480000      14.000000       0.670000    8399.980000
#
#          postal_code      region_id
# count  192888.000000  999795.000000
# mean    55348.941095    6370.559013
# std     32145.458536   10456.510728
# min      1040.000000      38.000000
# 25%     23320.000000    2125.000000
# 50%     57103.000000    3688.000000
# 75%     90049.000000    5636.000000
# max     99301.000000   98923.000000

# %%
df_orders.ship_mode.value_counts()
# Out:
# Standard Class    405356
# Second Class      335758
# Same Day          206222
# First Class        52655
# Name: ship_mode, dtype: int64

# %%
df_orders.ship_date.nunique()
# Out:
# 1502

# %%
df_products = pd.read_csv('./products.csv')

# %%
df_products.shape
# Out:
# (10292, 5)

# %%
df_products.index
# Out:
# RangeIndex(start=0, stop=10292, step=1)

# %%
df_products.dtypes
# Out:
# product_id                   object
# category                     object
# sub_category                 object
# product_name                 object
# product_cost_to_consumer    float64
# dtype: object

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10292 entries, 0 to 10291
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   product_id                10292 non-null  object
#  1   category                  10292 non-null  object
#  2   sub_category              10292 non-null  object
#  3   product_name              10292 non-null  object
#  4   product_cost_to_consumer  10292 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 402.2+ KB

# %%
df_2nd_class_orders = df_orders[df_orders['ship_mode']=='Second Class']

df_2nd_class_orders['profit'].mean()
# Out:
# 1.0517047992868271

# %%
print(df_orders[df_orders['order_date']=='2017-06-08']['product_id'].value_counts())
# Out:
# OFF-ST-10001963     4
# OFF-ST-10001426     3
# OFF-AR-10003875     3
# TEC-AC-10001840     3
# OFF-LA-10002295     2
#                    ..
# FUR-BO-10000676     1
# OFF-LA-10004430     1
# OFF-LA-10004062     1
# TEC-MA-10003704     1
# OFF-GRE-10003899    1
# Name: product_id, Length: 308, dtype: int64

# %% [markdown]
#     ## OS

# %%
import os

# %%
def display_cwd():
    cwd = os.getcwd()
    print('Current Working Directory: ', cwd)

if __name__ == '_main_':
    display_cwd()
print(display_cwd())
# Out:
# Current Working Directory:  f:\李振寰\进修 PC\General Assembly\Week 8 & 9 Python\JupyterNoteBook
# None

# %% [markdown]
#     ## API

# %% [markdown]
#     ## Concat

# %%
import pandas as pd

df1 = pd.DataFrame([['a', 1], ['b', 2]], columns=['letter',
'number'])
df2 = pd.DataFrame([['c', 3], ['d', 4]], columns=['letter',
'number'])
df_with_more_rows = pd.concat([df1, df2])
df_with_more_columns = pd.concat([df1, df2], axis=1)

# %%
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
df_with_more_rows
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df_with_more_columns
# Out:
#   letter  number letter  number
# 0      a       1      c       3
# 1      b       2      d       4

# %% [markdown]
#     ## Join and Merge

# %%
# pd.merge(left_df, right_df, how, left_on, right_on)

# %% [markdown]
#      ## matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
foot = pd.read_csv('F:/李振寰/进修 PC/General Assembly/dataset/international_football_results.csv')

foot
# Out:
#              date home_team away_team  home_score  away_score      tournament  \
# 0      1872-11-30  Scotland   England           0           0        Friendly
# 1      1873-03-08   England  Scotland           4           2        Friendly
# 2      1874-03-07  Scotland   England           2           1        Friendly
# 3      1875-03-06   England  Scotland           2           2        Friendly
# 4      1876-03-04  Scotland   England           3           0        Friendly
# ...           ...       ...       ...         ...         ...             ...
# 39664  2018-07-06   Uruguay    France           0           2  FIFA World Cup
# 39665  2018-07-06    Brazil   Belgium           1           2  FIFA World Cup
# 39666  2018-07-07    Sweden   England           0           2  FIFA World Cup
# 39667  2018-07-07    Russia   Croatia           2           2  FIFA World Cup
# 39668  2018-07-10    France   Belgium           1           0  FIFA World Cup
#
# ...

# %%
import random
import pandas as pd
print(random.randrange(1,10))
# Out:
# 5

# %% [markdown]
#     ## plotly

# %%
! pip install Pandas
# Out:
# ...
#   Using cached pandas-1.4.3-cp310-cp310-win_amd64.whl (10.5 MB)
# ...
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# ...

# %%
! pip install NumPy
# Out:
# ...
#      ---------------------------------------- 14.6/14.6 MB 4.9 MB/s eta 0:00:00
# ...

# %%
! pip install Plotly
# Out:
# ...
#   Using cached plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
# ...
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2 is available.
# You should consider upgrading via the 'C:\Users\user\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
! pip install cufflinks
# Out:
# ...
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# ...
#   Using cached ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
# ...
#   Using cached jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# ...
#   Using cached widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
# ...
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached notebook-6.4.12-py3-none-any.whl (9.9 MB)
# ...
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# ...
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# ...
#   Using cached nbconvert-6.5.0-py3-none-any.whl (561 kB)
# ...
#   Using cached terminado-0.15.0-py3-none-any.whl (16 kB)
# ...
#   Using cached prometheus_client-0.14.1-py3-none-any.whl (59 kB)
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#   Using cached nbformat-5.4.0-py3-none-any.whl (73 kB)
# ...

# %%
! pip install chart-studio
# Out:
# ...
#   Using cached chart_studio-1.1.0-py3-none-any.whl (64 kB)
# ...
#   Using cached retrying-1.3.3.tar.gz (10 kB)
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=717d2b143308d8f5efca3ae88e4139b5a71b17762b7dee97453269f360404db8
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...

# %%
! pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached scikit_learn-1.1.1-cp310-cp310-win_amd64.whl (7.3 MB)
# ...
#      -----------                              10.6/36.9 MB 2.8 MB/s eta 0:00:10
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 435, in _error_catcher
#     yield
#   File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\urllib3\response.py", line 516, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\http\client.py", line 465, in read
# ...

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import chart_studio.plotly as property
import plotly.tools as tls
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline
